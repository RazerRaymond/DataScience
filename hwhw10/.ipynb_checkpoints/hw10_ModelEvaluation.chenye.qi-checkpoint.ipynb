# %% [markdown]
# # Homework 10: Evaluating our Gesture Recognition NNs 🕸

# %% [markdown]
# Name: Chenye Qi
#
# Student ID: 475337
#
# Collaborators:

# %% [markdown]
# ## Instructions
#
# In our _last_ homework (woohoo!), we will be analyzing and evaluating the gesture recognition data and models created in `Lab10`. This is a great opportunity to recap the **Data Science workflow** with all its major aspects:
#
# - exploratory data analysis (EDA) and data profiling
# - machine learning workkflow
# - training, validation, testing data
# - model comparison
# - presenting results (creating plot)
#
# It will be extremely helpful to review **Lab 10 (Gesture Recognition with Neural Networks)** first.
#
# In general, you should feel free to import any package that we have previously used in class. Ensure that all plots have the necessary components that a plot should have (e.g. axes labels, a title, a legend).
#
# Furthermore, in addition to recording your collaborators on this homework, please also remember to cite/indicate all external sources used when finishing this assignment. This includes peers, TAs, and links to online sources. Note that these citations will not free you from your obligation to submit your _own_ code and write-ups, however, they will be taken into account during the grading and regrading process.
#
# ### Submission instructions
# * Submit this python notebook including your answers in the code cells as homework submission.
# * **Feel free to add as many cells as you need to** — just make sure you don't change what we gave you.
# * **Does it spark joy?** Note that you will be partially graded on the presentation (_cleanliness, clarity, comments_) of your notebook so make sure you [Marie Kondo](https://lifehacker.com/marie-kondo-is-not-a-verb-1833373654) your notebook before submitting it.

# %% [markdown]
# ## 1. Introduction
#
# The data needed for this assignemnt can be found [here](https://wustl.box.com/s/q8mnl1o2zq2bh0ca5zajtk3msnu03ou8). All of it was gathered in `Homework 10 (Part I)`:
# - training
# - validation
# - augmented
# - testing
#
# Here are the neural network models trained on `training`:
# - cse217_v1.h5 (still training; watch for announcement on Piazza)
# - cse217_v2.h5 (still training; watch for announcement on Piazza)
#
# Here are the neural network models trained on `augmented`:
# - cse217_v1_augmented.h5 (still training; watch for announcement on Piazza)
# - cse217_v2_augmented.h5 (still training; watch for announcement on Piazza)
#
# Note that to train these models we used the `validation` dataset to determine when to stop the training process.

# %% [markdown]
# ## 2. Test Data Collection, Data Profiling, and Model Understanding
#
# In this section, we will get a feel for our data.

# %% [markdown]
# ### Problem 0
#
# Following the instructions in `Lab10_DataAquisition` take 15 images of rock, paper, and scissors gestures (cf. `1.1 How To Take The Pictures`) and scale them using the provided code (`1.2 Storing, Scaling, and Sharing the Images`). Store them in a folder called `testing` along with the already collected data.

# %%
from os import makedirs, mkdir
from os.path import exists

base = 'utility/data'
raw = f'{base}/raw'
dirs = ['rock', 'paper', 'scissors']

if not exists(raw):
    makedirs(raw, exist_ok=True)

for sign in dirs:
    path = f'{raw}/{sign}'
    
    if not exists(path):
        mkdir(path)

# %% [markdown]
# **Try this!** Store the images you took of rocks (✊), papers (🤚), and scissors (✌️) in the correct folders in `utility/data/raw`. Then, run the following cell to produced rescaled images, which will be stored in `utility/data/testing`.

# %%
import os
import warnings
from utility.util import load_image, resize_image, save_image


testing = f'{base}/testing'

for sign in dirs:
    path = f'{testing}/{sign}'
    
    if not exists(path):
        makedirs(path, exist_ok=True)

for path, _, files in os.walk(raw):
    sign = os.path.basename(path)

    for file in files:
        if '.DS_Store' not in file:
            input_path = f'{path}/{file}'
            output_path = f'{testing}/{sign}/{file}'

            # note! warnings about lossy conversion are ok
            image = load_image(input_path)
            image = resize_image(image, (500, 500))

            save_image(output_path, image)
# Out:
# utility/data/raw/paper/IMG_9660.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/paper/IMG_9661.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/paper/IMG_9663.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/paper/IMG_9662.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/paper/IMG_9659.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/rock/IMG_9653.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/rock/IMG_9650.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/rock/IMG_9651.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/rock/IMG_9648.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/rock/IMG_9649.jpg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/scissors/IMG_9658.jpeg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/scissors/IMG_9654.jpeg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/scissors/IMG_9655.jpeg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/scissors/IMG_9656.jpeg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# utility/data/raw/scissors/IMG_9657.jpeg
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# ### Problem 1
#
# **Write-up!**  Report the number of images per class in each of the four datasets. Are the dataset balanced? No code submission required.
# > Hint: For most of this you can use the code from `Lab10_Model` with light modifications.

# %% [raw]
# | training | validation | testing | augmented
#         rock (c0) |
#        paper (c1) |
#     scissors (c2) |
#
#
# # your response here
# traning: 264 scissor, 260 paper, 266 rock
# validation: 66 scissor, 67 paper, 66 rock
# testing: 5 scissor, 5 paper, 5 rock
# augmented: 1262 scissor, 1257 paper, 1243 rock
#
# The dataset is approximately balanced

# %% [markdown]
# ### Problem 2
# Now, let's look at our models.
#
# **Write-up!**  Compare the following statistics for all four models:
# - number of parameters
# - number of convolutional layers
# - number of dense layers
# - size of the model (`.h5`) file
#
# What are the most surprising aspects of these statistics to you?

# %%
from tensorflow.keras.models import load_model

cse217_v1 = load_model('/Users/apple/Desktop/s20/217a /hw10_part2/utility/models/model.v1.raw.h5', compile=False)
cse217_v2 = load_model('/Users/apple/Desktop/s20/217a /hw10_part2/utility/models/model.v2.raw.h5', compile=False)
cse217_v1_augmented = load_model('/Users/apple/Desktop/s20/217a /hw10_part2/utility/models/model.v1.augmented.h5', compile=False)
cse217_v2_augmented = load_model('/Users/apple/Desktop/s20/217a /hw10_part2/utility/models/model.v2.augmented.h5', compile=False)

cse217_v1.summary()
cse217_v2.summary()
cse217_v1_augmented.summary()
cse217_v2_augmented.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 5)       140
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 124, 124, 5)       230
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 5)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 5)         230
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 5)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 5)         230
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 5)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 5)         230
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 5)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 180)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               23168
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 24,615
# Trainable params: 24,615
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 128)       3584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 1,741,571
# Trainable params: 1,741,571
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 126, 126, 5)       140
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 124, 124, 5)       230
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 5)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 60, 60, 5)         230
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 5)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 5)         230
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 5)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 12, 12, 5)         230
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 5)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 180)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               23168
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 24,615
# Trainable params: 24,615
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 128)       3584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 1,741,571
# Trainable params: 1,741,571
# Non-trainable params: 0
# _________________________________________________________________

# %% [raw]
# # your response here
#                       | # parameters | # conv layers | # dense layers | file size
#             cse217_v1 |   24,615     |       5       |        2       |    20MB
#             cse217_v2 |  1,741,571   |       3       |        2       |    20MB
#   cse217_v1_augmented |   24,615     |       5       |        2       |    367KB
#   cse217_v2_augmented |  1,741,571   |       3       |        2       |    367KB
#
# I'm surprised that it seems like the file size is unrelated to the # parameters or # conv layers. And I'm also surprised that the augmented data make the model smaller in file size.

# %% [markdown]
# ## 3. Model Comparison: v1 vs v2
#
# By now we should know all of the ins and outs about our datasets and models (right?). Let's evaluate and compare the models.

# %% [markdown]
# ### Problem 3
#
# First let's investiage which of the two versions `cse217_v1` or `cse217_v2` performs better in the non-augmented setting. You can use the code provided in the *updated version* of  `Lab10_Model` under `5. Evaluate Neural Network on Validation Data` with light modifications.
#
# **Write-up** For both versions report the accuracy on all three datasets `training`, `validation`, and `testing` and summarize your findings.
# - Which model performs better? Justify your answer based on the presented accuraccies.
# - Argue whether we can be happy with the perfomrance of our model. If yes, justify why, if no, give suggestions on how to imporve the performance.

# %% [markdown]
# In the following cell, we provide an example of how to load the testing. Note the dimensions of the dataset (especially the size of the images).

# %%
from utility.util import load_dataset

target_shape = (500, 500)
X_test_example, y_test_example = load_dataset('utility/data/testing', target_shape)
# Out:
# utility/data/testing/paper/IMG_9660.jpg
# utility/data/testing/paper/IMG_9661.jpg
# utility/data/testing/paper/IMG_9663.jpg
# utility/data/testing/paper/IMG_9662.jpg
# utility/data/testing/paper/IMG_9659.jpg
# utility/data/testing/rock/IMG_9653.jpg
# utility/data/testing/rock/IMG_9650.jpg
# utility/data/testing/rock/IMG_9651.jpg
# utility/data/testing/rock/IMG_9648.jpg
# utility/data/testing/rock/IMG_9649.jpg
# utility/data/testing/scissors/IMG_9658.jpeg
# utility/data/testing/scissors/IMG_9654.jpeg
# utility/data/testing/scissors/IMG_9655.jpeg
# utility/data/testing/scissors/IMG_9656.jpeg
# utility/data/testing/scissors/IMG_9657.jpeg

# %%
import skimage
import numpy as np
def accuracy(X, y, model):
    acc = 0
    label =  y
    image = X
    patchsize = model.input_shape[1]
    for i in range(0,len(X)):
        image_tran = skimage.transform.resize(image[i], (patchsize,patchsize))
        outs = model.predict(np.array([image_tran]))
        predicted = np.argmax(outs)
        if label[i][predicted] == 1:
            acc+=1
    
    print("Number of pictures predicted correctly by model: %d" % acc)
    print("Number of picutres in the dataset: %d" % len(X))

    return acc/len(X)


# Compute Model Performance
target_shape = (500, 500)
X_train_example, y_train_example = load_dataset('utility/data/Raw_data/training', target_shape)
v1_training = accuracy(X_train_example, y_train_example, cse217_v1) 
print('Accuracy of v1_training =', v1_training)
v2_training = accuracy(X_train_example, y_train_example, cse217_v2) 
print('Accuracy of v2_training =', v2_training)

target_shape = (500, 500)
X_val_example, y_val_example = load_dataset('utility/data/Raw_data/validation', target_shape)
v1_val = accuracy(X_val_example, y_val_example, cse217_v1) 
print('Accuracy of v1_val =', v1_val)
v2_val = accuracy(X_val_example, y_val_example, cse217_v2) 
print('Accuracy of v2_val =', v2_val)

v1_test = accuracy(X_test_example, y_test_example, cse217_v1) 
print('Accuracy of v1_test =', v1_test)
v2_test = accuracy(X_test_example, y_test_example, cse217_v2) 
print('Accuracy of v2_test =', v2_test)
# Out:
# utility/data/Raw_data/training/paper/IMG_7436.jpeg
# utility/data/Raw_data/training/paper/IMG_0996.JPG
# utility/data/Raw_data/training/paper/IMG_5150.jpg
# utility/data/Raw_data/training/paper/IMG_1849.jpg
# utility/data/Raw_data/training/paper/IMG_0598.jpeg
# utility/data/Raw_data/training/paper/paper5n.jpg
# utility/data/Raw_data/training/paper/IMG_6636.jpeg
# utility/data/Raw_data/training/paper/IMG_6266.jpeg
# utility/data/Raw_data/training/paper/IMG_6504.jpg
# utility/data/Raw_data/training/paper/paper2jche.JPG
# utility/data/Raw_data/training/paper/IMG_7322.jpeg
# utility/data/Raw_data/training/paper/20200420_184236.jpg
# utility/data/Raw_data/training/paper/IMG_20200423_204825.jpg
# utility/data/Raw_data/training/paper/Paper.jpg
# utility/data/Raw_data/training/paper/paper3zzhao.jpg
# utility/data/Raw_data/training/paper/IMG_1451.JPG
# utility/data/Raw_data/training/paper/IMG_0997.JPG
# utility/data/Raw_data/training/paper/IMG_5151.jpg
# utility/data/Raw_data/training/paper/paper2zzhao.jpg
# utility/data/Raw_data/training/paper/IMG_2116.jpeg
# utility/data/Raw_data/training/paper/IMG_5386.jpg
# utility/data/Raw_data/training/paper/IMG_1651.jpg
# utility/data/Raw_data/training/paper/IMG_0097.jpeg
# utility/data/Raw_data/training/paper/IMG_7142.PNG
# utility/data/Raw_data/training/paper/IMG_5225.jpg
# utility/data/Raw_data/training/paper/IMG_6512.jpg
# utility/data/Raw_data/training/paper/IMG_1527.jpg
# utility/data/Raw_data/training/paper/IMG_20200423_151108112.jpg
# utility/data/Raw_data/training/paper/IMG-1981.jpg
# utility/data/Raw_data/training/paper/IMG_2588.jpg
# utility/data/Raw_data/training/paper/IMG_1650.jpg
# utility/data/Raw_data/training/paper/IMG_1644.jpg
# utility/data/Raw_data/training/paper/IMG_5387.jpg
# utility/data/Raw_data/training/paper/IMG_20200423_204601.jpg
# utility/data/Raw_data/training/paper/IMG-6468 (1).jpg
# utility/data/Raw_data/training/paper/IMG_9988.jpg
# utility/data/Raw_data/training/paper/Image 11.jpeg
# utility/data/Raw_data/training/paper/PAPER1LAB10.jpg
# utility/data/Raw_data/training/paper/94128039_177562080037773_1466744195011051520_n.jpg
# utility/data/Raw_data/training/paper/IMG_1641.jpg
# utility/data/Raw_data/training/paper/IMG_9989.jpg
# utility/data/Raw_data/training/paper/IMG_6338.JPG
# utility/data/Raw_data/training/paper/IMG_20200423_151039519.jpg
# utility/data/Raw_data/training/paper/IMG_20200423_151114845.jpg
# utility/data/Raw_data/training/paper/IMG_1643.jpg
# utility/data/Raw_data/training/paper/IMG_1938.JPG
# utility/data/Raw_data/training/paper/IMG_2028.JPG
# utility/data/Raw_data/training/paper/IMG-1978.jpg
# utility/data/Raw_data/training/paper/IMG_1254 2.jpeg
# utility/data/Raw_data/training/paper/paper3jche.JPG
# utility/data/Raw_data/training/paper/20200420_184233.jpg
# utility/data/Raw_data/training/paper/IMG_7145.PNG
# utility/data/Raw_data/training/paper/IMG_3647-Copy1.jpg
# utility/data/Raw_data/training/paper/94207753_959390134481555_1516703722749558784_n.jpg
# utility/data/Raw_data/training/paper/IMG_7437.jpeg
# utility/data/Raw_data/training/paper/IMG_0088.jpg
# utility/data/Raw_data/training/paper/IMG_0705.jpg
# utility/data/Raw_data/training/paper/thumbnail_IMG_0350.jpg
# utility/data/Raw_data/training/paper/IMG_1534.HEIC
# utility/data/Raw_data/training/paper/WIN_20200420_20_29_39_Pro.jpg
# utility/data/Raw_data/training/paper/IMG_9319.jpg
# utility/data/Raw_data/training/paper/Paper4.jpg
# utility/data/Raw_data/training/paper/paper5.jpg
# utility/data/Raw_data/training/paper/IMG_9318.jpg
# utility/data/Raw_data/training/paper/thumbnail_IMG_0345.jpg
# utility/data/Raw_data/training/paper/IMG_3557.jpg
# utility/data/Raw_data/training/paper/thumbnail_IMG_0351.jpg
# utility/data/Raw_data/training/paper/IMG_0704.jpg
# utility/data/Raw_data/training/paper/IMG_2215.jpeg
# utility/data/Raw_data/training/paper/IMG_0089.jpg
# utility/data/Raw_data/training/paper/IMG_0706.jpg
# utility/data/Raw_data/training/paper/IMG_5468.JPG
# utility/data/Raw_data/training/paper/paper10.jpg
# utility/data/Raw_data/training/paper/paper3n.jpg
# utility/data/Raw_data/training/paper/IMG_7135.PNG
# utility/data/Raw_data/training/paper/IMG_20200423_151110515.jpg
# utility/data/Raw_data/training/paper/paper7.jpg
# utility/data/Raw_data/training/paper/IMG_1578.JPG
# utility/data/Raw_data/training/paper/IMG_7135.JPG
# utility/data/Raw_data/training/paper/IMG_7134.JPG
# utility/data/Raw_data/training/paper/IMG_2064.jpg
# utility/data/Raw_data/training/paper/wpaper2.jpg
# utility/data/Raw_data/training/paper/WeChat Image_20200424001459.jpg
# utility/data/Raw_data/training/paper/IMG_5469.JPG
# utility/data/Raw_data/training/paper/WeChat Image_20200424001505.jpg
# utility/data/Raw_data/training/paper/WeChat Image_20200424001511.jpg
# utility/data/Raw_data/training/paper/IMG_2219.jpeg
# utility/data/Raw_data/training/paper/IMG_3554.jpg
# utility/data/Raw_data/training/paper/paper1jche.JPG
# utility/data/Raw_data/training/paper/IMG_4213.JPG
# utility/data/Raw_data/training/paper/IMG_0908.JPG
# utility/data/Raw_data/training/paper/IMG_2218.jpeg
# utility/data/Raw_data/training/paper/IMG_0703.jpg
# utility/data/Raw_data/training/paper/Photo on 4-23-20 at 7.21 AM.jpg
# utility/data/Raw_data/training/paper/WIN_20200420_20_29_43_Pro.jpg
# utility/data/Raw_data/training/paper/IMG_2060.jpg
# utility/data/Raw_data/training/paper/Paper2.jpg
# utility/data/Raw_data/training/paper/IMG_2061.jpg
# utility/data/Raw_data/training/paper/Paper3.jpg
# utility/data/Raw_data/training/paper/IMG_7131.JPG
# utility/data/Raw_data/training/paper/paper2n.jpg
# utility/data/Raw_data/training/paper/paper4zzhao.jpg
# utility/data/Raw_data/training/paper/IMG_0702.jpg
# utility/data/Raw_data/training/paper/IMG_3673-Copy1.jpg
# utility/data/Raw_data/training/paper/Photo on 4-22-20 at 2.28 PM #2.jpg
# utility/data/Raw_data/training/paper/IMG_1634.jpg
# utility/data/Raw_data/training/paper/20200420_184245.jpg
# utility/data/Raw_data/training/paper/IMG_0338.jpg
# utility/data/Raw_data/training/paper/IMG_9320.jpg
# utility/data/Raw_data/training/paper/IMG_7133.JPG
# utility/data/Raw_data/training/paper/IMG_0112.JPG
# utility/data/Raw_data/training/paper/paper1.jpg
# utility/data/Raw_data/training/paper/paper0.jpg
# utility/data/Raw_data/training/paper/IMG_2062.jpg
# utility/data/Raw_data/training/paper/IMG_9335.jpg
# utility/data/Raw_data/training/paper/wpaper4.jpg
# utility/data/Raw_data/training/paper/IMG_8017.JPG
# utility/data/Raw_data/training/paper/IMG_3803.JPG
# utility/data/Raw_data/training/paper/IMG_1535.HEIC
# utility/data/Raw_data/training/paper/IMG_1635.jpg
# utility/data/Raw_data/training/paper/Photo on 4-22-20 at 2.28 PM #3.jpg
# utility/data/Raw_data/training/paper/IMG_2658.jpg
# utility/data/Raw_data/training/paper/IMG_2217.jpeg
# utility/data/Raw_data/training/paper/IMG_2655.jpg
# utility/data/Raw_data/training/paper/p3.jpg
# utility/data/Raw_data/training/paper/IMG_0485.JPG
# utility/data/Raw_data/training/paper/IMG_6645.jpeg
# utility/data/Raw_data/training/paper/IMG_6023.jpg
# utility/data/Raw_data/training/paper/tpaper1.jpg
# utility/data/Raw_data/training/paper/Image 14.jpeg
# utility/data/Raw_data/training/paper/paper4paper.jpg
# utility/data/Raw_data/training/paper/IMG_8027.JPG
# utility/data/Raw_data/training/paper/IMG_6022.jpg
# utility/data/Raw_data/training/paper/paper33.jpg
# utility/data/Raw_data/training/paper/p2.jpg
# utility/data/Raw_data/training/paper/IMG_2654.jpg
# utility/data/Raw_data/training/paper/IMG_2656.jpg
# utility/data/Raw_data/training/paper/IMG_3548.jpg
# utility/data/Raw_data/training/paper/IMG_3212.jpg
# utility/data/Raw_data/training/paper/94458623_245476626576357_152227968981139456_n.jpg
# utility/data/Raw_data/training/paper/IMG_3560.jpg
# utility/data/Raw_data/training/paper/IMG_8569.JPG
# utility/data/Raw_data/training/paper/IMG_3676-Copy1.jpg
# utility/data/Raw_data/training/paper/IMG_0120.JPG
# utility/data/Raw_data/training/paper/rescaled4.jpg
# utility/data/Raw_data/training/paper/tpaper3.jpg
# utility/data/Raw_data/training/paper/PAPER2LAB10.jpg
# utility/data/Raw_data/training/paper/PAPER3LAB10.jpg
# utility/data/Raw_data/training/paper/paper2345345.jpg
# utility/data/Raw_data/training/paper/paper1n.jpg
# utility/data/Raw_data/training/paper/p1.jpg
# utility/data/Raw_data/training/paper/IMG_3213.JPG
# utility/data/Raw_data/training/paper/IMG_2657.jpg
# utility/data/Raw_data/training/paper/IMG_2653.jpg
# utility/data/Raw_data/training/paper/IMG_6275.jpeg
# utility/data/Raw_data/training/paper/WeChat Image_20200424001508.jpg
# utility/data/Raw_data/training/paper/Photo on 4-23-20 at 7.26 AM.jpg
# utility/data/Raw_data/training/paper/IMG_5470.JPG
# utility/data/Raw_data/training/paper/p5.jpg
# utility/data/Raw_data/training/paper/94258301_266924464470492_2966573674154426368_n.jpg
# utility/data/Raw_data/training/paper/IMG_7139.PNG
# utility/data/Raw_data/training/paper/IMG_6025.jpg
# utility/data/Raw_data/training/paper/IMG_1986.jpg
# utility/data/Raw_data/training/paper/paper4jche.JPG
# utility/data/Raw_data/training/paper/rescaled1.jpg
# utility/data/Raw_data/training/paper/IMG_0119.JPG
# utility/data/Raw_data/training/paper/IMG_1575.JPG
# utility/data/Raw_data/training/paper/IMG_6024.jpg
# utility/data/Raw_data/training/paper/p4.jpg
# utility/data/Raw_data/training/paper/IMG_0910.JPG
# utility/data/Raw_data/training/paper/WIN_20200420_20_29_47_Pro.jpg
# utility/data/Raw_data/training/paper/IMG_0906.JPG
# utility/data/Raw_data/training/paper/IMG_0090.jpg
# utility/data/Raw_data/training/paper/IMG_3214.JPG
# utility/data/Raw_data/training/paper/IMG_8725.jpeg
# utility/data/Raw_data/training/paper/thumbnail_IMG_0348.jpg
# utility/data/Raw_data/training/paper/IMG_5467.JPG
# utility/data/Raw_data/training/paper/IMG_1577.JPG
# utility/data/Raw_data/training/paper/IMG_0133.JPG
# utility/data/Raw_data/training/paper/rescaled3.jpg
# utility/data/Raw_data/training/paper/rescaled2.jpg
# utility/data/Raw_data/training/paper/IMG_1576.JPG
# utility/data/Raw_data/training/paper/IMG_0867.JPG
# utility/data/Raw_data/training/paper/paper22.jpg
# utility/data/Raw_data/training/paper/IMG_20200423_204645.jpg
# utility/data/Raw_data/training/paper/thumbnail_IMG_0349.jpg
# utility/data/Raw_data/training/paper/IMG_3215.JPG
# utility/data/Raw_data/training/paper/paper1zzhao.jpg
# utility/data/Raw_data/training/paper/IMG_0907.JPG
# utility/data/Raw_data/training/paper/4.jpg
# utility/data/Raw_data/training/paper/IMG_6336.JPG
# utility/data/Raw_data/training/paper/IMG_1897.jpg
# utility/data/Raw_data/training/paper/IMG_2434.jpg
# utility/data/Raw_data/training/paper/IMG_5373.jpg
# utility/data/Raw_data/training/paper/IMG-1975.jpg
# utility/data/Raw_data/training/paper/IMG_6524.jpg
# utility/data/Raw_data/training/paper/IMG_2019.JPG
# utility/data/Raw_data/training/paper/IMG_2025.JPG
# utility/data/Raw_data/training/paper/Paper 1.jpg
# utility/data/Raw_data/training/paper/WIN_20200420_20_29_45_Pro.jpg
# utility/data/Raw_data/training/paper/paper44.jpg
# utility/data/Raw_data/training/paper/IMG_1896.jpg
# utility/data/Raw_data/training/paper/IMG_4911.jpg
# utility/data/Raw_data/training/paper/IMG_1855.jpg
# utility/data/Raw_data/training/paper/IMG_9992.jpg
# utility/data/Raw_data/training/paper/IMG_6337.JPG
# utility/data/Raw_data/training/paper/IMG_7434.jpeg
# utility/data/Raw_data/training/paper/5.jpg
# utility/data/Raw_data/training/paper/IMG_4285.jpg
# utility/data/Raw_data/training/paper/IMG_6335.JPG
# utility/data/Raw_data/training/paper/IMG_7759.jpg
# utility/data/Raw_data/training/paper/IMG_9990.jpg
# utility/data/Raw_data/training/paper/Photo on 4-23-20 at 7.26 AM #2.jpg
# utility/data/Raw_data/training/paper/IMG_1894.jpg
# utility/data/Raw_data/training/paper/IMG_5370.jpg
# utility/data/Raw_data/training/paper/Photo on 4-22-20 at 2.27 PM #6.jpg
# utility/data/Raw_data/training/paper/Paper 3.jpg
# utility/data/Raw_data/training/paper/Paper 2.jpg
# utility/data/Raw_data/training/paper/Image 12.jpeg
# utility/data/Raw_data/training/paper/Photo on 4-22-20 at 2.27 PM #7.jpg
# utility/data/Raw_data/training/paper/IMG_5371.jpg
# utility/data/Raw_data/training/paper/IMG_1895.jpg
# utility/data/Raw_data/training/paper/IMG_4912.jpg
# utility/data/Raw_data/training/paper/IMG_4286.jpg
# utility/data/Raw_data/training/paper/IMG_4282.jpg
# utility/data/Raw_data/training/paper/2.jpg
# utility/data/Raw_data/training/paper/IMG_0999.JPG
# utility/data/Raw_data/training/paper/IMG_1846.jpg
# utility/data/Raw_data/training/paper/IMG_1852.jpg
# utility/data/Raw_data/training/paper/d.png
# utility/data/Raw_data/training/paper/IMG_1649.jpg
# utility/data/Raw_data/training/paper/IMG_1531.HEIC
# utility/data/Raw_data/training/paper/IMG_6269.jpeg
# utility/data/Raw_data/training/paper/IMG_6639.jpeg
# utility/data/Raw_data/training/paper/IMG_6522.jpg
# utility/data/Raw_data/training/paper/Image 13.jpeg
# utility/data/Raw_data/training/paper/IMG_2023.JPG
# utility/data/Raw_data/training/paper/94624216_159517542104879_9146173040546021376_n.jpg
# utility/data/Raw_data/training/paper/IMG_0344.jpg
# utility/data/Raw_data/training/paper/IMG_0350.jpg
# utility/data/Raw_data/training/paper/paper3paper.jpg
# utility/data/Raw_data/training/paper/20200420_184239.jpg
# utility/data/Raw_data/training/paper/IMG_6642.jpeg
# utility/data/Raw_data/training/paper/e.png
# utility/data/Raw_data/training/paper/IMG_5374.jpg
# utility/data/Raw_data/training/paper/IMG_0998.JPG
# utility/data/Raw_data/training/paper/3.jpg
# utility/data/Raw_data/training/paper/IMG_4283.jpg
# utility/data/Raw_data/training/paper/IMG_7435.jpeg
# utility/data/Raw_data/training/paper/1.jpg
# utility/data/Raw_data/training/paper/IMG_5148.jpg
# utility/data/Raw_data/training/paper/IMG_6273.jpeg
# utility/data/Raw_data/training/paper/IMG_5389.jpg
# utility/data/Raw_data/training/paper/g.png
# utility/data/Raw_data/training/paper/IMG-6464 (1).jpg
# utility/data/Raw_data/training/paper/IMG_20200423_204753.jpg
# utility/data/Raw_data/training/paper/IMG_3650-Copy1.jpg
# utility/data/Raw_data/training/paper/IMG_0346.jpg
# utility/data/Raw_data/training/paper/Paper 4.jpg
# utility/data/Raw_data/training/paper/Photo on 4-23-20 at 7.20 AM #2.jpg
# utility/data/Raw_data/training/paper/IMG-1971.jpg
# utility/data/Raw_data/training/paper/Photo on 4-23-20 at 7.20 AM.jpg
# utility/data/Raw_data/training/paper/PAPER5LAB10.jpg
# utility/data/Raw_data/training/paper/f.png
# utility/data/Raw_data/training/paper/IMG_5388.jpg
# utility/data/Raw_data/training/paper/IMG_5149.jpg
# utility/data/Raw_data/training/rock/IMG_2603.jpg
# utility/data/Raw_data/training/rock/rock1zzhao.jpg
# utility/data/Raw_data/training/rock/IMG_5391.jpg
# utility/data/Raw_data/training/rock/IMG_1652.jpg
# utility/data/Raw_data/training/rock/IMG_1646.jpg
# utility/data/Raw_data/training/rock/IMG_7141.PNG
# utility/data/Raw_data/training/rock/IMG_20200423_205119.jpg
# utility/data/Raw_data/training/rock/IMG_1518.jpg
# utility/data/Raw_data/training/rock/IMG_6505.jpg
# utility/data/Raw_data/training/rock/IMG_7140.JPG
# utility/data/Raw_data/training/rock/IMG_1519.jpg
# utility/data/Raw_data/training/rock/IMG_6510.jpg
# utility/data/Raw_data/training/rock/rock4jche.JPG
# utility/data/Raw_data/training/rock/IMG_1848.jpg
# utility/data/Raw_data/training/rock/IMG_7034.JPG
# utility/data/Raw_data/training/rock/IMG_5153.jpg
# utility/data/Raw_data/training/rock/IMG_5392.jpg
# utility/data/Raw_data/training/rock/IMG_1645.jpg
# utility/data/Raw_data/training/rock/IMG-1980.jpg
# utility/data/Raw_data/training/rock/IMG_9961.jpeg
# utility/data/Raw_data/training/rock/rock5n.jpg
# utility/data/Raw_data/training/rock/IMG_6507.jpg
# utility/data/Raw_data/training/rock/IMG_0348.jpg
# utility/data/Raw_data/training/rock/IMG_6641.jpeg
# utility/data/Raw_data/training/rock/IMG_5393.jpg
# utility/data/Raw_data/training/rock/IMG_2836.jpg
# utility/data/Raw_data/training/rock/IMG_0990.JPG
# utility/data/Raw_data/training/rock/IMG_5156.jpg
# utility/data/Raw_data/training/rock/IMG_1640.jpg
# utility/data/Raw_data/training/rock/ROCK2LAB10.jpg
# utility/data/Raw_data/training/rock/ROCK3LAB10.jpg
# utility/data/Raw_data/training/rock/IMG_1907.jpg
# utility/data/Raw_data/training/rock/rock4n.jpg
# utility/data/Raw_data/training/rock/IMG_2572.jpg
# utility/data/Raw_data/training/rock/IMG_1906.jpg
# utility/data/Raw_data/training/rock/WIN_20200420_20_29_14_Pro.jpg
# utility/data/Raw_data/training/rock/IMG_0991.JPG
# utility/data/Raw_data/training/rock/IMG_4288.jpg
# utility/data/Raw_data/training/rock/IMG_5155.jpg
# utility/data/Raw_data/training/rock/IMG_0993.JPG
# utility/data/Raw_data/training/rock/IMG_5394.jpg
# utility/data/Raw_data/training/rock/IMG_4908.jpg
# utility/data/Raw_data/training/rock/IMG_5357.jpg
# utility/data/Raw_data/training/rock/IMG_7144.PNG
# utility/data/Raw_data/training/rock/IMG_1904.jpg
# utility/data/Raw_data/training/rock/IMG_20200423_151106110.jpg
# utility/data/Raw_data/training/rock/qqqq.png
# utility/data/Raw_data/training/rock/IMG_4470.JPG
# utility/data/Raw_data/training/rock/IMG_2029.JPG
# utility/data/Raw_data/training/rock/IMG_1520.jpg
# utility/data/Raw_data/training/rock/IMG_7186.JPG
# utility/data/Raw_data/training/rock/IMG_2798.JPG
# utility/data/Raw_data/training/rock/IMG_1905.jpg
# utility/data/Raw_data/training/rock/IMG_2224.jpeg
# utility/data/Raw_data/training/rock/IMG_6267.jpeg
# utility/data/Raw_data/training/rock/IMG_4909.jpg
# utility/data/Raw_data/training/rock/IMG_6271.jpeg
# utility/data/Raw_data/training/rock/IMG_5154.jpg
# utility/data/Raw_data/training/rock/IMG_0992.JPG
# utility/data/Raw_data/training/rock/IMG_4289.jpg
# utility/data/Raw_data/training/rock/IMG_2660.jpg
# utility/data/Raw_data/training/rock/94377537_2542546856000210_6059336652856229888_n.jpg
# utility/data/Raw_data/training/rock/IMG_3556.jpg
# utility/data/Raw_data/training/rock/IMG_5480.JPG
# utility/data/Raw_data/training/rock/r2.jpg
# utility/data/Raw_data/training/rock/Rock3.jpg
# utility/data/Raw_data/training/rock/IMG_7136.PNG
# utility/data/Raw_data/training/rock/IMG_9325.jpg
# utility/data/Raw_data/training/rock/ROCK4LAB10.jpg
# utility/data/Raw_data/training/rock/IMG_2066.jpg
# utility/data/Raw_data/training/rock/rock11.jpg
# utility/data/Raw_data/training/rock/rock10.jpg
# utility/data/Raw_data/training/rock/wrock1.jpg
# utility/data/Raw_data/training/rock/IMG_7137.JPG
# utility/data/Raw_data/training/rock/IMG_2067.jpg
# utility/data/Raw_data/training/rock/IMG_9324.jpg
# utility/data/Raw_data/training/rock/20200420_184255.jpg
# utility/data/Raw_data/training/rock/IMG_6956.JPG
# utility/data/Raw_data/training/rock/IMG_7490.JPG
# utility/data/Raw_data/training/rock/Rock2.jpg
# utility/data/Raw_data/training/rock/r3.jpg
# utility/data/Raw_data/training/rock/IMG_5481.JPG
# utility/data/Raw_data/training/rock/IMG_6349.JPG
# utility/data/Raw_data/training/rock/IMG_2429.jpeg
# utility/data/Raw_data/training/rock/IMG_2661.jpg
# utility/data/Raw_data/training/rock/IMG_2850.jpg
# utility/data/Raw_data/training/rock/IMG_7430.jpeg
# utility/data/Raw_data/training/rock/IMG_2663.jpg
# utility/data/Raw_data/training/rock/thumbnail_IMG_0347.jpg
# utility/data/Raw_data/training/rock/IMG_6276.jpeg
# utility/data/Raw_data/training/rock/IMG_6149.jpg
# utility/data/Raw_data/training/rock/IMG_4027.jpeg
# utility/data/Raw_data/training/rock/r1.jpg
# utility/data/Raw_data/training/rock/IMG_2223.jpeg
# utility/data/Raw_data/training/rock/IMG_6029.jpg
# utility/data/Raw_data/training/rock/94124108_2948170608598983_5890870207097864192_n.jpg
# utility/data/Raw_data/training/rock/IMG_0128.JPG
# utility/data/Raw_data/training/rock/wrock3.jpg
# utility/data/Raw_data/training/rock/wrock2.jpg
# utility/data/Raw_data/training/rock/IMG_0129.JPG
# utility/data/Raw_data/training/rock/IMG_6028.jpg
# utility/data/Raw_data/training/rock/IMG_9333.jpg
# utility/data/Raw_data/training/rock/IMG_3675-Copy1.jpg
# utility/data/Raw_data/training/rock/Rock1.jpg
# utility/data/Raw_data/training/rock/IMG_2662.jpg
# utility/data/Raw_data/training/rock/IMG_3550.jpg
# utility/data/Raw_data/training/rock/thumbnail_IMG_0356.jpg
# utility/data/Raw_data/training/rock/IMG_2666.jpg
# utility/data/Raw_data/training/rock/rock5.jpg
# utility/data/Raw_data/training/rock/IMG_1637.jpg
# utility/data/Raw_data/training/rock/r4.jpg
# utility/data/Raw_data/training/rock/IMG_5479.JPG
# utility/data/Raw_data/training/rock/WIN_20200420_20_29_21_Pro.jpg
# utility/data/Raw_data/training/rock/IMG_7332.jpg
# utility/data/Raw_data/training/rock/IMG_9323.jpg
# utility/data/Raw_data/training/rock/IMG_1582.JPG
# utility/data/Raw_data/training/rock/IMG_7119.JPG
# utility/data/Raw_data/training/rock/IMG_1583.JPG
# utility/data/Raw_data/training/rock/Rock.jpg
# utility/data/Raw_data/training/rock/IMG_2222.jpeg
# utility/data/Raw_data/training/rock/IMG_5478.JPG
# utility/data/Raw_data/training/rock/IMG_1636.jpg
# utility/data/Raw_data/training/rock/rock4rock.jpg
# utility/data/Raw_data/training/rock/Rock4.jpg
# utility/data/Raw_data/training/rock/IMG_9281.JPG
# utility/data/Raw_data/training/rock/thumbnail_IMG_0357.jpg
# utility/data/Raw_data/training/rock/IMG_7431.jpeg
# utility/data/Raw_data/training/rock/IMG_3553.jpg
# utility/data/Raw_data/training/rock/IMG_2665.jpg
# utility/data/Raw_data/training/rock/20200420_184251.jpg
# utility/data/Raw_data/training/rock/IMG_20200423_151100714.jpg
# utility/data/Raw_data/training/rock/IMG_1581.JPG
# utility/data/Raw_data/training/rock/rock2n.jpg
# utility/data/Raw_data/training/rock/wrock4.jpg
# utility/data/Raw_data/training/rock/IMG_1580.JPG
# utility/data/Raw_data/training/rock/WIN_20200420_20_29_17_Pro.jpg
# utility/data/Raw_data/training/rock/IMG_2664.jpg
# utility/data/Raw_data/training/rock/Photo on 4-22-20 at 2.26 PM #5.jpg
# utility/data/Raw_data/training/rock/IMG_5751.jpeg
# utility/data/Raw_data/training/rock/thumbnail_IMG_0359.jpg
# utility/data/Raw_data/training/rock/IMG_3563.jpg
# utility/data/Raw_data/training/rock/IMG_3646-Copy1 (1).jpg
# utility/data/Raw_data/training/rock/20200420_184249.jpg
# utility/data/Raw_data/training/rock/IMG_0693.jpg
# utility/data/Raw_data/training/rock/rock1n.jpg
# utility/data/Raw_data/training/rock/img4.jpg
# utility/data/Raw_data/training/rock/IMG_0692.jpg
# utility/data/Raw_data/training/rock/thumbnail_IMG_0358.jpg
# utility/data/Raw_data/training/rock/Photo on 4-22-20 at 2.26 PM #4.jpg
# utility/data/Raw_data/training/rock/rock3jche.JPG
# utility/data/Raw_data/training/rock/IMG_0914.JPG
# utility/data/Raw_data/training/rock/IMG_9379.jpeg
# utility/data/Raw_data/training/rock/Photo on 4-23-20 at 7.28 AM.jpg
# utility/data/Raw_data/training/rock/ROCK1LAB10.jpg
# utility/data/Raw_data/training/rock/rock1rock.jpg
# utility/data/Raw_data/training/rock/IMG-6466 (1).jpg
# utility/data/Raw_data/training/rock/Photo on 4-23-20 at 7.27 AM #2.jpg
# utility/data/Raw_data/training/rock/Photo on 4-23-20 at 7.27 AM #3.jpg
# utility/data/Raw_data/training/rock/WIN_20200420_20_29_24_Pro.jpg
# utility/data/Raw_data/training/rock/IMG_0336.jpg
# utility/data/Raw_data/training/rock/IMG_2221.jpeg
# utility/data/Raw_data/training/rock/rock8.jpg
# utility/data/Raw_data/training/rock/IMG_0915.JPG
# utility/data/Raw_data/training/rock/IMG_7432.jpeg
# utility/data/Raw_data/training/rock/qqq.png
# utility/data/Raw_data/training/rock/IMG_0083.jpg
# utility/data/Raw_data/training/rock/Image.jpeg
# utility/data/Raw_data/training/rock/IMG_3571.JPG
# utility/data/Raw_data/training/rock/Photo on 4-22-20 at 2.26 PM #3.jpg
# utility/data/Raw_data/training/rock/IMG_6347.JPG
# utility/data/Raw_data/training/rock/rock2jche.JPG
# utility/data/Raw_data/training/rock/WeChat Image_20200424001440.jpg
# utility/data/Raw_data/training/rock/img3.jpg
# utility/data/Raw_data/training/rock/IMG_0695.jpg
# utility/data/Raw_data/training/rock/IMG_2069.jpg
# utility/data/Raw_data/training/rock/IMG_7139.JPG
# utility/data/Raw_data/training/rock/IMG_7138.JPG
# utility/data/Raw_data/training/rock/IMG_0131.JPG
# utility/data/Raw_data/training/rock/IMG_2068.jpg
# utility/data/Raw_data/training/rock/Image 3.jpeg
# utility/data/Raw_data/training/rock/IMG_0694.jpg
# utility/data/Raw_data/training/rock/img2.jpg
# utility/data/Raw_data/training/rock/Photo on 4-23-20 at 7.27 AM #6.jpg
# utility/data/Raw_data/training/rock/IMG_6030.jpg
# utility/data/Raw_data/training/rock/IMG_7138.PNG
# utility/data/Raw_data/training/rock/20200420_184306.jpg
# utility/data/Raw_data/training/rock/Photo on 4-22-20 at 2.26 PM #2.jpg
# utility/data/Raw_data/training/rock/IMG_6346.JPG
# utility/data/Raw_data/training/rock/IMG_3570.jpg
# utility/data/Raw_data/training/rock/IMG_0086.jpg
# utility/data/Raw_data/training/rock/qq.png
# utility/data/Raw_data/training/rock/IMG_0912.JPG
# utility/data/Raw_data/training/rock/IMG_0084.jpg
# utility/data/Raw_data/training/rock/IMG_3572.JPG
# utility/data/Raw_data/training/rock/IMG_3651-Copy1.jpg
# utility/data/Raw_data/training/rock/rock3zzhao.jpg
# utility/data/Raw_data/training/rock/rock2zzhao.jpg
# utility/data/Raw_data/training/rock/20200420_184258.jpg
# utility/data/Raw_data/training/rock/IMG_20200423_151058589.jpg
# utility/data/Raw_data/training/rock/Photo on 4-23-20 at 7.27 AM #4.jpg
# utility/data/Raw_data/training/rock/IMG_0696.jpg
# utility/data/Raw_data/training/rock/IMG_7429.jpeg
# utility/data/Raw_data/training/rock/IMG_0132.JPG
# utility/data/Raw_data/training/rock/img1.jpg
# utility/data/Raw_data/training/rock/IMG_6027.jpg
# utility/data/Raw_data/training/rock/IMG_6644.jpeg
# utility/data/Raw_data/training/rock/IMG_3670-Copy1.jpg
# utility/data/Raw_data/training/rock/IMG_6345.JPG
# utility/data/Raw_data/training/rock/IMG_3573.JPG
# utility/data/Raw_data/training/rock/IMG_0085.jpg
# utility/data/Raw_data/training/rock/IMG_0913.JPG
# utility/data/Raw_data/training/rock/IMG_4290.jpg
# utility/data/Raw_data/training/rock/4.jpg
# utility/data/Raw_data/training/rock/IMG_1854.jpg
# utility/data/Raw_data/training/rock/IMG_4910.jpg
# utility/data/Raw_data/training/rock/rock2rock.jpg
# utility/data/Raw_data/training/rock/Rock 2.jpg
# utility/data/Raw_data/training/rock/Image 4.jpeg
# utility/data/Raw_data/training/rock/IMG-1974.jpg
# utility/data/Raw_data/training/rock/IMG_0342.jpg
# utility/data/Raw_data/training/rock/Rock 3.jpg
# utility/data/Raw_data/training/rock/IMG_6272.jpeg
# utility/data/Raw_data/training/rock/IMG_9979.jpg
# utility/data/Raw_data/training/rock/5.jpg
# utility/data/Raw_data/training/rock/IMG_4291.jpg
# utility/data/Raw_data/training/rock/rock4zzhao.jpg
# utility/data/Raw_data/training/rock/IMG_4907.jpg
# utility/data/Raw_data/training/rock/IMG_5358.jpg
# utility/data/Raw_data/training/rock/IMG_1923.jpg
# utility/data/Raw_data/training/rock/Rock 1.jpg
# utility/data/Raw_data/training/rock/IMG_2027.JPG
# utility/data/Raw_data/training/rock/IMG-1977.jpg
# utility/data/Raw_data/training/rock/IMG_20200423_151103270.jpg
# utility/data/Raw_data/training/rock/IMG_6638.jpeg
# utility/data/Raw_data/training/rock/WeChat Image_20200424001433.jpg
# utility/data/Raw_data/training/rock/IMG_5359.jpg
# utility/data/Raw_data/training/rock/IMG_1842.jpg
# utility/data/Raw_data/training/rock/2.jpg
# utility/data/Raw_data/training/rock/Rock 4.jpg
# utility/data/Raw_data/training/rock/93856322_1114384425571451_7685104842385129472_n.jpg
# utility/data/Raw_data/training/rock/WeChat Image_20200424001437.jpg
# utility/data/Raw_data/training/rock/IMG_0345.jpg
# utility/data/Raw_data/training/rock/IMG_20200423_205102.jpg
# utility/data/Raw_data/training/rock/IMG_1517.jpg
# utility/data/Raw_data/training/rock/IMG_2022.JPG
# utility/data/Raw_data/training/rock/IMG_6523.jpg
# utility/data/Raw_data/training/rock/IMG_0393.JPG
# utility/data/Raw_data/training/rock/WeChat Image_20200424001422.jpg
# utility/data/Raw_data/training/rock/IMG_5360.jpg
# utility/data/Raw_data/training/rock/IMG_9980.jpg
# utility/data/Raw_data/training/rock/3.jpg
# utility/data/Raw_data/training/rock/rock3rock.jpg
# utility/data/Raw_data/training/rock/1.jpg
# utility/data/Raw_data/training/rock/IMG_9982.jpg
# utility/data/Raw_data/training/rock/IMG_1845.jpg
# utility/data/Raw_data/training/rock/fakf.png
# utility/data/Raw_data/training/rock/IMG_6635.jpeg
# utility/data/Raw_data/training/rock/rock2134234242.jpg
# utility/data/Raw_data/training/rock/rock1jche.JPG
# utility/data/Raw_data/training/rock/IMG-1970.jpg
# utility/data/Raw_data/training/rock/IMG_20200423_205115.jpg
# utility/data/Raw_data/training/rock/IMG_2020.JPG
# utility/data/Raw_data/training/rock/Image 5.jpeg
# utility/data/Raw_data/training/rock/94488506_242129667151862_2255491870652104704_n.jpg
# utility/data/Raw_data/training/rock/IMG_9983.jpg
# utility/data/Raw_data/training/rock/IMG_20200423_205048.jpg
# utility/data/Raw_data/training/scissors/Photo on 4-23-20 at 7.28 AM #3.jpg
# utility/data/Raw_data/training/scissors/WIN_20200420_20_29_51_Pro.jpg
# utility/data/Raw_data/training/scissors/IMG_6270.jpeg
# utility/data/Raw_data/training/scissors/IMG_1901.jpg
# utility/data/Raw_data/training/scissors/IMG_6511.jpg
# utility/data/Raw_data/training/scissors/scissors2n.jpg
# utility/data/Raw_data/training/scissors/IMG_1524.jpg
# utility/data/Raw_data/training/scissors/IMG_3455.jpg
# utility/data/Raw_data/training/scissors/IMG_7140.JPG
# utility/data/Raw_data/training/scissors/IMG_1525.jpg
# utility/data/Raw_data/training/scissors/IMG-1982.jpg
# utility/data/Raw_data/training/scissors/sci3jche.JPG
# utility/data/Raw_data/training/scissors/Photo on 4-23-20 at 7.29 AM.jpg
# utility/data/Raw_data/training/scissors/Image 6.jpeg
# utility/data/Raw_data/training/scissors/IMG_9347.JPG
# utility/data/Raw_data/training/scissors/IMG_7140.PNG
# utility/data/Raw_data/training/scissors/IMG_1900.jpg
# utility/data/Raw_data/training/scissors/IMG_1647.jpg
# utility/data/Raw_data/training/scissors/IMG_1653.jpg
# utility/data/Raw_data/training/scissors/IMG_5384.jpg
# utility/data/Raw_data/training/scissors/Photo on 4-23-20 at 7.28 AM #2.jpg
# utility/data/Raw_data/training/scissors/IMG_4298.jpg
# utility/data/Raw_data/training/scissors/SCISSORS1LAB10.jpg
# utility/data/Raw_data/training/scissors/IMG_1902.jpg
# utility/data/Raw_data/training/scissors/IMG_2229.jpeg
# utility/data/Raw_data/training/scissors/Image 10.jpeg
# utility/data/Raw_data/training/scissors/IMG_6506.jpg
# utility/data/Raw_data/training/scissors/IMG_3456.JPG
# utility/data/Raw_data/training/scissors/IMG_3457.JPG
# utility/data/Raw_data/training/scissors/IMG_1526.jpg
# utility/data/Raw_data/training/scissors/feafe.png
# utility/data/Raw_data/training/scissors/IMG_7143.PNG
# utility/data/Raw_data/training/scissors/IMG_3674-Copy1.jpg
# utility/data/Raw_data/training/scissors/IMG_7441.jpeg
# utility/data/Raw_data/training/scissors/IMG_7440.jpeg
# utility/data/Raw_data/training/scissors/IMG_5383.jpg
# utility/data/Raw_data/training/scissors/IMG_7219.JPG
# utility/data/Raw_data/training/scissors/IMG_6640.jpeg
# utility/data/Raw_data/training/scissors/IMG_0452.jpeg
# utility/data/Raw_data/training/scissors/WIN_20200420_20_29_49_Pro.jpg
# utility/data/Raw_data/training/scissors/IMG_1523.jpg
# utility/data/Raw_data/training/scissors/IMG_20200423_151054318.jpg
# utility/data/Raw_data/training/scissors/IMG_2228.jpeg
# utility/data/Raw_data/training/scissors/IMG_7146.PNG
# utility/data/Raw_data/training/scissors/IMG_1899.jpg
# utility/data/Raw_data/training/scissors/IMG_20200423_151050963.jpg
# utility/data/Raw_data/training/scissors/IMG_5382.jpg
# utility/data/Raw_data/training/scissors/faef.png
# utility/data/Raw_data/training/scissors/IMG-1979.jpg
# utility/data/Raw_data/training/scissors/Image 7.jpeg
# utility/data/Raw_data/training/scissors/scissors11.jpg
# utility/data/Raw_data/training/scissors/scissors3n.jpg
# utility/data/Raw_data/training/scissors/sci2jche.JPG
# utility/data/Raw_data/training/scissors/IMG_6637.jpeg
# utility/data/Raw_data/training/scissors/IMG_3690.JPG
# utility/data/Raw_data/training/scissors/IMG_1642.jpg
# utility/data/Raw_data/training/scissors/IMG_5381.jpg
# utility/data/Raw_data/training/scissors/IMG_2660.jpg
# utility/data/Raw_data/training/scissors/Photo on 4-23-20 at 7.29 AM #3.jpg
# utility/data/Raw_data/training/scissors/sci1zzhao.jpg
# utility/data/Raw_data/training/scissors/IMG_2072.jpg
# utility/data/Raw_data/training/scissors/94425153_226299125345652_2141919028241760256_n.jpg
# utility/data/Raw_data/training/scissors/IMG_7137.JPG
# utility/data/Raw_data/training/scissors/IMG_0102.jpg
# utility/data/Raw_data/training/scissors/IMG_2073.jpg
# utility/data/Raw_data/training/scissors/Photo on 4-23-20 at 7.29 AM #2.jpg
# utility/data/Raw_data/training/scissors/IMG_9330.jpg
# utility/data/Raw_data/training/scissors/IMG_7137.PNG
# utility/data/Raw_data/training/scissors/20200420_184321.jpg
# utility/data/Raw_data/training/scissors/IMG_0921.JPG
# utility/data/Raw_data/training/scissors/IMG_3555.jpg
# utility/data/Raw_data/training/scissors/thumbnail_IMG_0353.jpg
# utility/data/Raw_data/training/scissors/20200420_184323.jpg
# utility/data/Raw_data/training/scissors/94259779_871740533311770_1108693657969491968_n.jpg
# utility/data/Raw_data/training/scissors/Scissor4.jpg
# utility/data/Raw_data/training/scissors/s5.jpg
# utility/data/Raw_data/training/scissors/IMG_0699.jpg
# utility/data/Raw_data/training/scissors/WIN_20200420_20_29_52_Pro.jpg
# utility/data/Raw_data/training/scissors/IMG_2071.jpg
# utility/data/Raw_data/training/scissors/scissors4n.jpg
# utility/data/Raw_data/training/scissors/IMG_2070.jpg
# utility/data/Raw_data/training/scissors/IMG_0101.jpg
# utility/data/Raw_data/training/scissors/s4.jpg
# utility/data/Raw_data/training/scissors/thumbnail_IMG_0352.jpg
# utility/data/Raw_data/training/scissors/thumbnail_IMG_0346.jpg
# utility/data/Raw_data/training/scissors/IMG_0920.JPG
# utility/data/Raw_data/training/scissors/IMG_0918.JPG
# utility/data/Raw_data/training/scissors/IMG_7050.jpg
# utility/data/Raw_data/training/scissors/IMG_2672.jpg
# utility/data/Raw_data/training/scissors/scissors9.jpg
# utility/data/Raw_data/training/scissors/Scissor1.jpg
# utility/data/Raw_data/training/scissors/WeChat Image_20200424001449.jpg
# utility/data/Raw_data/training/scissors/IMG_4607.JPG
# utility/data/Raw_data/training/scissors/scissors5n.jpg
# utility/data/Raw_data/training/scissors/94390391_1159638731041529_2828957025000488960_n.jpg
# utility/data/Raw_data/training/scissors/sci1jche.JPG
# utility/data/Raw_data/training/scissors/afeaf.png
# utility/data/Raw_data/training/scissors/s1.jpg
# utility/data/Raw_data/training/scissors/IMG_6277.jpeg
# utility/data/Raw_data/training/scissors/20200420_184327.jpg
# utility/data/Raw_data/training/scissors/IMG_2667.jpg
# utility/data/Raw_data/training/scissors/IMG_8410.jpg
# utility/data/Raw_data/training/scissors/IMG_0099.jpg
# utility/data/Raw_data/training/scissors/thumbnail_IMG_0355.jpg
# utility/data/Raw_data/training/scissors/IMG_2659.jpg
# utility/data/Raw_data/training/scissors/IMG_2665.jpg
# utility/data/Raw_data/training/scissors/IMG_0700.jpg
# utility/data/Raw_data/training/scissors/IMG_1185.JPG
# utility/data/Raw_data/training/scissors/20200420_184319.jpg
# utility/data/Raw_data/training/scissors/s3.jpg
# utility/data/Raw_data/training/scissors/scissors.jpg
# utility/data/Raw_data/training/scissors/Scissor2.jpg
# utility/data/Raw_data/training/scissors/IMG_6646.jpeg
# utility/data/Raw_data/training/scissors/IMG_9334.jpg
# utility/data/Raw_data/training/scissors/IMG_20200423_204936.jpg
# utility/data/Raw_data/training/scissors/IMG_20200423_151047649.jpg
# utility/data/Raw_data/training/scissors/IMG_9679.JPG
# utility/data/Raw_data/training/scissors/IMG_1999.jpg
# utility/data/Raw_data/training/scissors/Scissor3.jpg
# utility/data/Raw_data/training/scissors/IMG_20200423_204857.jpg
# utility/data/Raw_data/training/scissors/s2.jpg
# utility/data/Raw_data/training/scissors/20200420_184324.jpg
# utility/data/Raw_data/training/scissors/IMG_2670.jpg
# utility/data/Raw_data/training/scissors/IMG_0701.jpg
# utility/data/Raw_data/training/scissors/IMG_3552.jpg
# utility/data/Raw_data/training/scissors/IMG_2658.jpg
# utility/data/Raw_data/training/scissors/thumbnail_IMG_0354.jpg
# utility/data/Raw_data/training/scissors/94574508_163982451584274_8151333468035350528_n.jpg
# utility/data/Raw_data/training/scissors/IMG_0098.jpg
# utility/data/Raw_data/training/scissors/IMG_0917.JPG
# utility/data/Raw_data/training/scissors/scissors6.jpg
# utility/data/Raw_data/training/scissors/IMG_1638.jpg
# utility/data/Raw_data/training/scissors/IMG_5476.JPG
# utility/data/Raw_data/training/scissors/IMG_1002.JPG
# utility/data/Raw_data/training/scissors/IMG_0122.JPG
# utility/data/Raw_data/training/scissors/IMG_1572.JPG
# utility/data/Raw_data/training/scissors/IMG_1573.JPG
# utility/data/Raw_data/training/scissors/IMG_0123.JPG
# utility/data/Raw_data/training/scissors/IMG_1003.JPG
# utility/data/Raw_data/training/scissors/IMG_1639.jpg
# utility/data/Raw_data/training/scissors/scissors7.jpg
# utility/data/Raw_data/training/scissors/IMG_6340.JPG
# utility/data/Raw_data/training/scissors/IMG_6342.JPG
# utility/data/Raw_data/training/scissors/IMG_5475.JPG
# utility/data/Raw_data/training/scissors/Scissors 4.jpg
# utility/data/Raw_data/training/scissors/sci4zzhao.jpg
# utility/data/Raw_data/training/scissors/sci4jche.JPG
# utility/data/Raw_data/training/scissors/IMG_0337.jpg
# utility/data/Raw_data/training/scissors/IMG_6034.jpg
# utility/data/Raw_data/training/scissors/IMG_1571.JPG
# utility/data/Raw_data/training/scissors/IMG_1570.JPG
# utility/data/Raw_data/training/scissors/IMG_0134.JPG
# utility/data/Raw_data/training/scissors/IMG_6035.jpg
# utility/data/Raw_data/training/scissors/IMG_8636.jpg
# utility/data/Raw_data/training/scissors/IMG_5474.JPG
# utility/data/Raw_data/training/scissors/IMG_5448.JPG
# utility/data/Raw_data/training/scissors/IMG_6274.jpeg
# utility/data/Raw_data/training/scissors/afef.png
# utility/data/Raw_data/training/scissors/scissors4.jpg
# utility/data/Raw_data/training/scissors/IMG_3561.jpg
# utility/data/Raw_data/training/scissors/IMG_6343.JPG
# utility/data/Raw_data/training/scissors/IMG_2657.jpg
# utility/data/Raw_data/training/scissors/IMG_0726.jpg
# utility/data/Raw_data/training/scissors/SCISSORS2LAB10.jpg
# utility/data/Raw_data/training/scissors/SCISSORS3LAB10.jpg
# utility/data/Raw_data/training/scissors/Scissors 1.jpg
# utility/data/Raw_data/training/scissors/IMG_1004.JPG
# utility/data/Raw_data/training/scissors/IMG_20200423_204914.jpg
# utility/data/Raw_data/training/scissors/IMG_7139.JPG
# utility/data/Raw_data/training/scissors/scissors44.jpg
# utility/data/Raw_data/training/scissors/IMG_0124.JPG
# utility/data/Raw_data/training/scissors/IMG_7138.JPG
# utility/data/Raw_data/training/scissors/IMG_1005.JPG
# utility/data/Raw_data/training/scissors/WeChat Image_20200424001455.jpg
# utility/data/Raw_data/training/scissors/IMG_3669-Copy1.jpg
# utility/data/Raw_data/training/scissors/scissors1.jpg
# utility/data/Raw_data/training/scissors/IMG_3558.jpg
# utility/data/Raw_data/training/scissors/IMG_20200423_205002.jpg
# utility/data/Raw_data/training/scissors/IMG_6344.JPG
# utility/data/Raw_data/training/scissors/scissors3.jpg
# utility/data/Raw_data/training/scissors/IMG_5473.JPG
# utility/data/Raw_data/training/scissors/WeChat Image_20200424001443.jpg
# utility/data/Raw_data/training/scissors/Scissors 2.jpg
# utility/data/Raw_data/training/scissors/IMG_9329.jpg
# utility/data/Raw_data/training/scissors/IMG_8779.JPG
# utility/data/Raw_data/training/scissors/IMG_6032.jpg
# utility/data/Raw_data/training/scissors/IMG_3645-Copy1.jpg
# utility/data/Raw_data/training/scissors/IMG_0697.jpg
# utility/data/Raw_data/training/scissors/IMG_6033.jpg
# utility/data/Raw_data/training/scissors/IMG_9328.jpg
# utility/data/Raw_data/training/scissors/Scissors 3.jpg
# utility/data/Raw_data/training/scissors/scissors2.jpg
# utility/data/Raw_data/training/scissors/wscissors4.jpg
# utility/data/Raw_data/training/scissors/4.jpg
# utility/data/Raw_data/training/scissors/IMG_9978.jpg
# utility/data/Raw_data/training/scissors/IMG-6465 (1).jpg
# utility/data/Raw_data/training/scissors/IMG_5159.jpg
# utility/data/Raw_data/training/scissors/IMG_9987.jpg
# utility/data/Raw_data/training/scissors/94510946_219159649373987_1493523595274485760_n.jpg
# utility/data/Raw_data/training/scissors/SCISSORS4LAB10.jpg
# utility/data/Raw_data/training/scissors/IMG_0343.jpg
# utility/data/Raw_data/training/scissors/Photo on 4-22-20 at 2.27 PM #5.jpg
# utility/data/Raw_data/training/scissors/IMG_0419.JPG
# utility/data/Raw_data/training/scissors/IMG_6295.jpg
# utility/data/Raw_data/training/scissors/IMG_2030.JPG
# utility/data/Raw_data/training/scissors/IMG_2024.JPG
# utility/data/Raw_data/training/scissors/Photo on 4-22-20 at 2.27 PM #4.jpg
# utility/data/Raw_data/training/scissors/IMG_2227.jpeg
# utility/data/Raw_data/training/scissors/IMG_5366.jpg
# utility/data/Raw_data/training/scissors/IMG_9986.jpg
# utility/data/Raw_data/training/scissors/5.jpg
# utility/data/Raw_data/training/scissors/IMG_4293.jpg
# utility/data/Raw_data/training/scissors/IMG_4913.jpg
# utility/data/Raw_data/training/scissors/IMG_5364.jpg
# utility/data/Raw_data/training/scissors/IMG_20200423_151057191.jpg
# utility/data/Raw_data/training/scissors/IMG_6643.jpeg
# utility/data/Raw_data/training/scissors/IMG-1976.jpg
# utility/data/Raw_data/training/scissors/scissors22.jpg
# utility/data/Raw_data/training/scissors/IMG_3463.jpg
# utility/data/Raw_data/training/scissors/IMG_2026.JPG
# utility/data/Raw_data/training/scissors/IMG_6268.jpeg
# utility/data/Raw_data/training/scissors/IMG_0341.jpg
# utility/data/Raw_data/training/scissors/IMG_5365.jpg
# utility/data/Raw_data/training/scissors/IMG_9985.jpg
# utility/data/Raw_data/training/scissors/2.jpg
# utility/data/Raw_data/training/scissors/wscissors2.jpg
# utility/data/Raw_data/training/scissors/IMG_9981.jpg
# utility/data/Raw_data/training/scissors/IMG_7439.jpeg
# utility/data/Raw_data/training/scissors/IMG_4916.jpg
# utility/data/Raw_data/training/scissors/IMG_3649-Copy1.jpg
# utility/data/Raw_data/training/scissors/Photo on 4-22-20 at 2.27 PM #3.jpg
# utility/data/Raw_data/training/scissors/scissors33.jpg
# utility/data/Raw_data/training/scissors/Image 9.jpeg
# utility/data/Raw_data/training/scissors/IMG-1972.jpg
# utility/data/Raw_data/training/scissors/Photo on 4-22-20 at 2.27 PM #2.jpg
# utility/data/Raw_data/training/scissors/ss02.jpg
# utility/data/Raw_data/training/scissors/IMG_1853.jpg
# utility/data/Raw_data/training/scissors/IMG_1847.jpg
# utility/data/Raw_data/training/scissors/IMG_5162.jpg
# utility/data/Raw_data/training/scissors/wscissors3.jpg
# utility/data/Raw_data/training/scissors/3.jpg
# utility/data/Raw_data/training/scissors/IMG_7442.jpeg
# utility/data/Raw_data/training/scissors/IMG_4295.jpg
# utility/data/Raw_data/training/scissors/wscissors1.jpg
# utility/data/Raw_data/training/scissors/1.jpg
# utility/data/Raw_data/training/scissors/IMG_5160.jpg
# utility/data/Raw_data/training/scissors/IMG_4915.jpg
# utility/data/Raw_data/training/scissors/IMG_2226.jpeg
# utility/data/Raw_data/training/scissors/IMG_4134.jpg
# utility/data/Raw_data/training/scissors/sci2zzhao.jpg
# utility/data/Raw_data/training/scissors/sci3zzhao.jpg
# utility/data/Raw_data/training/scissors/IMG_6509.jpg
# utility/data/Raw_data/training/scissors/IMG_2021.JPG
# utility/data/Raw_data/training/scissors/IMG_6521.jpg
# utility/data/Raw_data/training/scissors/IMG_3458.JPG
# utility/data/Raw_data/training/scissors/WIN_20200420_20_29_54_Pro.jpg
# utility/data/Raw_data/training/scissors/IMG_0347.jpg
# utility/data/Raw_data/training/scissors/WeChat Image_20200424001409.jpg
# utility/data/Raw_data/training/scissors/IMG_5363.jpg
# utility/data/Raw_data/training/scissors/IMG_1844.jpg
# utility/data/Raw_data/training/scissors/IMG_1850.jpg
# utility/data/Raw_data/training/scissors/IMG_4914.jpg
# utility/data/Raw_data/training/scissors/IMG_5161.jpg
# utility/data/Raw_data/training/scissors/IMG_4294.jpg
# Number of pictures predicted correctly by model: 364
# Number of picutres in the dataset: 784
# Accuracy of v1_training = 0.4642857142857143
# Number of pictures predicted correctly by model: 450
# Number of picutres in the dataset: 784
# Accuracy of v2_training = 0.5739795918367347
# utility/data/Raw_data/validation/paper/IMG_5390.jpg
# utility/data/Raw_data/validation/paper/IMG_5147.jpg
# utility/data/Raw_data/validation/paper/IMG_9977.jpg
# utility/data/Raw_data/validation/paper/IMG_6339.JPG
# utility/data/Raw_data/validation/paper/IMG_1898.jpg
# utility/data/Raw_data/validation/paper/IMG-1984.jpg
# utility/data/Raw_data/validation/paper/20200420_184230.jpg
# utility/data/Raw_data/validation/paper/94207753_959390134481555_1516703722749558784_n.jpg
# utility/data/Raw_data/validation/paper/paper4.jpg
# utility/data/Raw_data/validation/paper/Paper5.jpg
# utility/data/Raw_data/validation/paper/IMG_9324.jpg
# utility/data/Raw_data/validation/paper/IMG_3184.jpg
# utility/data/Raw_data/validation/paper/IMG_3183.jpg
# utility/data/Raw_data/validation/paper/IMG_0139.JPG
# utility/data/Raw_data/validation/paper/IMG_7130.JPG
# utility/data/Raw_data/validation/paper/paper2.jpg
# utility/data/Raw_data/validation/paper/IMG_3182.jpg
# utility/data/Raw_data/validation/paper/paper5zzhao.jpg
# utility/data/Raw_data/validation/paper/WeChat Image_20200424001514.jpg
# utility/data/Raw_data/validation/paper/IMG_3551.jpg
# utility/data/Raw_data/validation/paper/IMG_2214.jpeg
# utility/data/Raw_data/validation/paper/wpaper5.jpg
# utility/data/Raw_data/validation/paper/Paper1.jpg
# utility/data/Raw_data/validation/paper/IMG_2063.jpg
# utility/data/Raw_data/validation/paper/IMG_0477.JPG
# utility/data/Raw_data/validation/paper/IMG_3181.jpg
# utility/data/Raw_data/validation/paper/IMG_1610.jpg
# utility/data/Raw_data/validation/paper/IMG_3198.jpg
# utility/data/Raw_data/validation/paper/IMG_0334.jpg
# utility/data/Raw_data/validation/paper/IMG_8027.JPG
# utility/data/Raw_data/validation/paper/IMG_1536.HEIC
# utility/data/Raw_data/validation/paper/IMG_6278.jpeg
# utility/data/Raw_data/validation/paper/IMG_2654.jpg
# utility/data/Raw_data/validation/paper/paper5jche.JPG
# utility/data/Raw_data/validation/paper/IMG_1001.JPG
# utility/data/Raw_data/validation/paper/rescaled5.jpg
# utility/data/Raw_data/validation/paper/p1.jpg
# utility/data/Raw_data/validation/paper/IMG_20200423_151020958.jpg
# utility/data/Raw_data/validation/paper/IMG_0911.JPG
# utility/data/Raw_data/validation/paper/IMG_0087.jpg
# utility/data/Raw_data/validation/paper/p5.jpg
# utility/data/Raw_data/validation/paper/IMG_9316.jpg
# utility/data/Raw_data/validation/paper/IMG_1574.JPG
# utility/data/Raw_data/validation/paper/IMG_6648.jpeg
# utility/data/Raw_data/validation/paper/IMG_2652.jpg
# utility/data/Raw_data/validation/paper/IMG_6026.jpg
# utility/data/Raw_data/validation/paper/Image 15.jpeg
# utility/data/Raw_data/validation/paper/IMG_5466.JPG
# utility/data/Raw_data/validation/paper/4.jpg
# utility/data/Raw_data/validation/paper/Photo on 4-22-20 at 2.28 PM.jpg
# utility/data/Raw_data/validation/paper/IMG_7149.PNG
# utility/data/Raw_data/validation/paper/IMG_20200423_204838.jpg
# utility/data/Raw_data/validation/paper/c.png
# utility/data/Raw_data/validation/paper/IMG_3644 (1) (1).jpg
# utility/data/Raw_data/validation/paper/5.jpg
# utility/data/Raw_data/validation/paper/IMG_1843.jpg
# utility/data/Raw_data/validation/paper/IMG_7438.jpeg
# utility/data/Raw_data/validation/paper/IMG_4279.jpg
# utility/data/Raw_data/validation/paper/IMG_2036.JPG
# utility/data/Raw_data/validation/paper/94624216_159517542104879_9146173040546021376_n.jpg
# utility/data/Raw_data/validation/paper/IMG_5376.jpg
# utility/data/Raw_data/validation/paper/Paper 5.jpg
# utility/data/Raw_data/validation/paper/IMG_6508.jpg
# utility/data/Raw_data/validation/paper/paper55.jpg
# utility/data/Raw_data/validation/paper/PAPER4LAB10.jpg
# utility/data/Raw_data/validation/paper/WIN_20200420_20_29_36_Pro.jpg
# utility/data/Raw_data/validation/rock/IMG-1983.jpg
# utility/data/Raw_data/validation/rock/IMG_5152.jpg
# utility/data/Raw_data/validation/rock/IMG_0994.JPG
# utility/data/Raw_data/validation/rock/IMG_7147.PNG
# utility/data/Raw_data/validation/rock/IMG_1521.jpg
# utility/data/Raw_data/validation/rock/WeChat Image_20200424001428.jpg
# utility/data/Raw_data/validation/rock/fafi.png
# utility/data/Raw_data/validation/rock/IMG_5395.jpg
# utility/data/Raw_data/validation/rock/IMG_3643 (1) (1).jpg
# utility/data/Raw_data/validation/rock/rock5jche.JPG
# utility/data/Raw_data/validation/rock/IMG_1369.JPG
# utility/data/Raw_data/validation/rock/94377537_2542546856000210_6059336652856229888_n.jpg
# utility/data/Raw_data/validation/rock/IMG_6348.JPG
# utility/data/Raw_data/validation/rock/IMG_3191.jpg
# utility/data/Raw_data/validation/rock/ROCK5LAB10.jpg
# utility/data/Raw_data/validation/rock/IMG_7136.JPG
# utility/data/Raw_data/validation/rock/rock3n.jpg
# utility/data/Raw_data/validation/rock/IMG_2663.jpg
# utility/data/Raw_data/validation/rock/IMG_20200423_151043207.jpg
# utility/data/Raw_data/validation/rock/rock0.jpg
# utility/data/Raw_data/validation/rock/IMG_3192.jpg
# utility/data/Raw_data/validation/rock/IMG_2065.jpg
# utility/data/Raw_data/validation/rock/IMG_1579.JPG
# utility/data/Raw_data/validation/rock/IMG_3193.jpg
# utility/data/Raw_data/validation/rock/Rock5.jpg
# utility/data/Raw_data/validation/rock/WIN_20200420_20_29_31_Pro.jpg
# utility/data/Raw_data/validation/rock/r5.jpg
# utility/data/Raw_data/validation/rock/IMG_20200423_205223.jpg
# utility/data/Raw_data/validation/rock/IMG_2659.jpg
# utility/data/Raw_data/validation/rock/IMG_6650.jpeg
# utility/data/Raw_data/validation/rock/IMG_3194.jpg
# utility/data/Raw_data/validation/rock/wrock5.jpg
# utility/data/Raw_data/validation/rock/IMG_9321.jpg
# utility/data/Raw_data/validation/rock/IMG_3195.jpg
# utility/data/Raw_data/validation/rock/20200420_184249.jpg
# utility/data/Raw_data/validation/rock/img5.jpg
# utility/data/Raw_data/validation/rock/IMG_5477.JPG
# utility/data/Raw_data/validation/rock/IMG_3562.jpg
# utility/data/Raw_data/validation/rock/IMG_0916.JPG
# utility/data/Raw_data/validation/rock/IMG_0082.jpg
# utility/data/Raw_data/validation/rock/Image 2.jpeg
# utility/data/Raw_data/validation/rock/IMG_0135.JPG
# utility/data/Raw_data/validation/rock/IMG_2535.jpg
# utility/data/Raw_data/validation/rock/IMG_7433.jpeg
# utility/data/Raw_data/validation/rock/IMG_2220.jpeg
# utility/data/Raw_data/validation/rock/IMG-6467 (1).jpg
# utility/data/Raw_data/validation/rock/IMG_6031.jpg
# utility/data/Raw_data/validation/rock/IMG_0333.jpg
# utility/data/Raw_data/validation/rock/20200420_184306.jpg
# utility/data/Raw_data/validation/rock/IMG_6280.jpeg
# utility/data/Raw_data/validation/rock/IMG_8793.jpg
# utility/data/Raw_data/validation/rock/rock_resize.png
# utility/data/Raw_data/validation/rock/IMG_1908.jpg
# utility/data/Raw_data/validation/rock/IMG_6519.jpg
# utility/data/Raw_data/validation/rock/5.jpg
# utility/data/Raw_data/validation/rock/IMG_4287.jpg
# utility/data/Raw_data/validation/rock/rock5zzhao.jpg
# utility/data/Raw_data/validation/rock/IMG_9984.jpg
# utility/data/Raw_data/validation/rock/IMG_2032.JPG
# utility/data/Raw_data/validation/rock/IMG_0393.JPG
# utility/data/Raw_data/validation/rock/Rock 5.jpg
# utility/data/Raw_data/validation/rock/1.jpg
# utility/data/Raw_data/validation/rock/IMG_1851.jpg
# utility/data/Raw_data/validation/rock/IMG_5362.jpg
# utility/data/Raw_data/validation/rock/Photo on 4-22-20 at 2.26 PM.jpg
# utility/data/Raw_data/validation/rock/94488506_242129667151862_2255491870652104704_n.jpg
# utility/data/Raw_data/validation/scissors/IMG_5385.jpg
# utility/data/Raw_data/validation/scissors/IMG_2225.jpeg
# utility/data/Raw_data/validation/scissors/IMG_7141.JPG
# utility/data/Raw_data/validation/scissors/IMG_3252.jpg
# utility/data/Raw_data/validation/scissors/IMG_5147.jpg
# utility/data/Raw_data/validation/scissors/IMG_1903.jpg
# utility/data/Raw_data/validation/scissors/IMG-1985.jpg
# utility/data/Raw_data/validation/scissors/IMG_5369.jpg
# utility/data/Raw_data/validation/scissors/IMG_4698.JPG
# utility/data/Raw_data/validation/scissors/IMG_0922.JPG
# utility/data/Raw_data/validation/scissors/94425153_226299125345652_2141919028241760256_n.jpg
# utility/data/Raw_data/validation/scissors/IMG_3190.jpg
# utility/data/Raw_data/validation/scissors/IMG_2661.jpg
# utility/data/Raw_data/validation/scissors/94259779_871740533311770_1108693657969491968_n.jpg
# utility/data/Raw_data/validation/scissors/s5.jpg
# utility/data/Raw_data/validation/scissors/IMG_3186.jpg
# utility/data/Raw_data/validation/scissors/IMG_20200423_151045071.jpg
# utility/data/Raw_data/validation/scissors/IMG_9327.jpg
# utility/data/Raw_data/validation/scissors/IMG_3187.jpg
# utility/data/Raw_data/validation/scissors/Scissor5.jpg
# utility/data/Raw_data/validation/scissors/IMG_1569.JPG
# utility/data/Raw_data/validation/scissors/IMG_2074.jpg
# utility/data/Raw_data/validation/scissors/s1.jpg
# utility/data/Raw_data/validation/scissors/Photo on 4-22-20 at 2.27 PM.jpg
# utility/data/Raw_data/validation/scissors/20200420_184327.jpg
# utility/data/Raw_data/validation/scissors/20200420_184319.jpg
# utility/data/Raw_data/validation/scissors/IMG_9679.JPG
# utility/data/Raw_data/validation/scissors/IMG_2664.jpg
# utility/data/Raw_data/validation/scissors/IMG_6341.JPG
# utility/data/Raw_data/validation/scissors/WeChat Image_20200424001452.jpg
# utility/data/Raw_data/validation/scissors/IMG_3642 (1) (1).jpg
# utility/data/Raw_data/validation/scissors/IMG_0137.JPG
# utility/data/Raw_data/validation/scissors/IMG_0335.jpg
# utility/data/Raw_data/validation/scissors/IMG_6036.jpg
# utility/data/Raw_data/validation/scissors/IMG_0096.jpg
# utility/data/Raw_data/validation/scissors/sci5zzhao.jpg
# utility/data/Raw_data/validation/scissors/IMG_6649.jpeg
# utility/data/Raw_data/validation/scissors/scissors55.jpg
# utility/data/Raw_data/validation/scissors/Scissors 5.jpg
# utility/data/Raw_data/validation/scissors/WIN_20200420_20_29_56_Pro.jpg
# utility/data/Raw_data/validation/scissors/IMG_3549.jpg
# utility/data/Raw_data/validation/scissors/IMG_4222.jpg
# utility/data/Raw_data/validation/scissors/scissors0.jpg
# utility/data/Raw_data/validation/scissors/sci5jche.JPG
# utility/data/Raw_data/validation/scissors/scissors1.jpg
# utility/data/Raw_data/validation/scissors/IMG_20200423_205016.jpg
# utility/data/Raw_data/validation/scissors/IMG_6279.jpeg
# utility/data/Raw_data/validation/scissors/IMG_1537.heic
# utility/data/Raw_data/validation/scissors/IMG_3189.jpg
# utility/data/Raw_data/validation/scissors/IMG_1006.JPG
# utility/data/Raw_data/validation/scissors/IMG_3188.jpg
# utility/data/Raw_data/validation/scissors/IMG_5472.JPG
# utility/data/Raw_data/validation/scissors/SCISSORS5LAB10.jpg
# utility/data/Raw_data/validation/scissors/afe.png
# utility/data/Raw_data/validation/scissors/IMG_7148.PNG
# utility/data/Raw_data/validation/scissors/IMG_6525.jpg
# utility/data/Raw_data/validation/scissors/5.jpg
# utility/data/Raw_data/validation/scissors/wscissors5.jpg
# utility/data/Raw_data/validation/scissors/IMG_7443.jpeg
# utility/data/Raw_data/validation/scissors/Image 8.jpeg
# utility/data/Raw_data/validation/scissors/IMG_1856.jpg
# utility/data/Raw_data/validation/scissors/IMG_4292.jpg
# utility/data/Raw_data/validation/scissors/2.jpg
# utility/data/Raw_data/validation/scissors/IMG_9981.jpg
# utility/data/Raw_data/validation/scissors/IMG_2037.JPG
# utility/data/Raw_data/validation/scissors/scissors1n.jpg
# Number of pictures predicted correctly by model: 84
# Number of picutres in the dataset: 195
# Accuracy of v1_val = 0.4307692307692308
# Number of pictures predicted correctly by model: 92
# Number of picutres in the dataset: 195
# Accuracy of v2_val = 0.4717948717948718
# Number of pictures predicted correctly by model: 9
# Number of picutres in the dataset: 15
# Accuracy of v1_test = 0.6
# Number of pictures predicted correctly by model: 11
# Number of picutres in the dataset: 15
# Accuracy of v2_test = 0.7333333333333333

# %% [raw]
# # your response here
#
#               | training acc | validation acc | testing acc
#     cse217_v1 |     0.46     |      0.43      |    0.6
#     cse217_v2 |     0.57     |      0.47      |    0.73
#
# Based on accuracy, v2 performs better in non-augmented data because it has higher accuracy in taining, validation, and testing.
# The accuracy is pretty low. Maybe we should apply model that used more data to train itself.

# %% [markdown]
# ### Problem 4
#
# Now, that we have summarized and analyzed the average performance of the models, let's look at individual images.
#
# **Write-up**  Using your own `testing` set and the better performing version that you identified in the previous problem, which of the three classes get predicted more correctly, which of the classes get mistaken for what other classes more frequently?
#
# > Hint: you may use the visualization implemented in the *updated version* of  `Lab10_Model` under `5. Evaluate Neural Network on Validation Data` (last code cell).

# %%
import pathlib
from tqdm import tqdm
import pandas as pd
def create_user_testdata(path2folder, foldername):
    dataset_directory = pathlib.Path(path2folder)

    # Now check the data
    ddir=dataset_directory/foldername
    cdirs={}
    cdirs.update({ddir/"rock":0,
                  ddir/"paper":1,
                  ddir/"scissors":2})

    names = ["rock", "paper", "scissors"]

    for cdir,cdir_class in cdirs.items():
        assert cdir.exists()==1, str(cdir)+' does not exist'
        print("Found directory {} containing class {}".format(cdir,names[cdir_class]))

    imagesize = 500
    dataset1=[]
    for cdir,cn in reversed(list(cdirs.items())):

        for f in tqdm(list(cdir.glob("*"))):
            try:
                im=skimage.io.imread(f)
                h,w=im.shape[0:2] # height, width
                sz=min(h,w)
                im=im[(h//2-sz//2):(h//2+sz//2),(w//2-sz//2):(w//2+sz//2),:] # defines the central square
                with warnings.catch_warnings():
                    warnings.simplefilter("ignore")
                    im=skimage.img_as_ubyte(skimage.transform.resize(im,(imagesize,imagesize))) # resize it to 500x500, whatever the original resolution
            except:
                warnings.warn("ignoring "+str(f))
                continue

            dataset1.append({
                "file": f,
                "label": cn,
                "image": im
            })

    print("Done")

    dataset1 = pd.DataFrame(dataset1)
    dataset1["dn"] = dataset1["file"].apply(lambda x: x.parent.parts[-2])
    return dataset1

# %%
data_for_evaluation = "testing"
base_directory = pathlib.Path("utility/data")
dataset_test = create_user_testdata(base_directory,data_for_evaluation)
# Out:
#  40%|████      | 2/5 [00:00<00:00, 15.11it/s]
# Found directory utility/data/testing/rock containing class rock
# Found directory utility/data/testing/paper containing class paper
# Found directory utility/data/testing/scissors containing class scissors
# 100%|██████████| 5/5 [00:00<00:00, 18.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 20.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.52it/s]
# Done

# %%
# Show results by processing a single validataion or testing image
import matplotlib.pyplot as plt
names = ["rock", "paper", "scissors"]

# %matplotlib inline
def resultsShow(i, data, model):
    guide = { 0:"rock",1:"paper",2:"scissor"}
    d = data.iloc[i]
    im = d["image"]
    l = d["label"]
    fig,axs = plt.subplots(nrows=1,ncols=3,figsize=(15,5),gridspec_kw={'width_ratios':[1,1,0.5]})
    
    imt = imr = skimage.transform.resize(im, (model.input_shape[1],model.input_shape[1]))
    axs[0].imshow(im)
    axs[0].set_title("Image (true class: {})".format(names[l]))
    
    axs[1].imshow(imt,interpolation="nearest")
    axs[1].set_title("Network input")
    
    outs = model.predict(np.array([imt]))
    predicted = np.argmax(outs)
    print(outs)
    print("predicted label, %s" % guide.get(predicted))
    print("actual label, %s"% guide.get(l))

    axs[2].bar(np.array(range(len(names)))-0.5, outs[0,:], 1, color="gray")
    axs[2].set_ylim([0,1])
    axs[2].set_xticks(range(len(names)))
    axs[2].set_xticklabels(names)
    axs[2].set_ylabel("probability")
    axs[2].set_xlabel("class")
    axs[2].set_title("Network output")
    fig.tight_layout()
    plt.show()
    #fig.savefig("out_{:05d}_{}.png".format(i,("ok" if predicted==l else "ko")))    
print("Results on individual {} inputs: ".format(dataset_test.loc[0].dn)) 
interact(resultsShow, i=widgets.IntSlider(min=0,max=len(dataset_test)-1, step=1, value=0, continuous_update=False), data=fixed(dataset_test.sample(len(dataset_test))), model=fixed(cse217_v2))
# Out:
# Results on individual testing inputs:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='i', max=14), Output()), _dom_cl…
# <function __main__.resultsShow(i, data, model)>

# %% [raw]
# # your response here
# All predictions of paper are wrong, 1 out of 5 predictions of rock is correct, and 4 out of 5 predictions of scissors are correct. Rock and paper gets mixed up the most.

# %% [markdown]
# ## 4. Model Comparison: original vs augmented
#
# Now, let's investiage whether data augmentation imporves performance.
#
#
# ### Problem 5
#
# Which of the models `cse217_vx`  or `cse217_vx_augmented` for both versions performs better? You can again use the code provided in the *updated version* of `Lab10_Model` under `5. Evaluate Neural Network on Validation Data` with light modifications.
#
# **Write-up** Report and compare the accuracy on all three datasets `training`, `validation`, and `testing` of the original and the augmented model for both versions. Summarize your findings.
# - Did data augemntation help?
# - Which of the two NN versions benefited or suffered more from data augmentation?
# - Give an explanation/guestimate why this is the case.

# %%
import skimage
import numpy as np
def accuracy(X, y, model):
    acc = 0
    label =  y
    image = X
    patchsize = model.input_shape[1]
    for i in range(0,len(X)):
        image_tran = skimage.transform.resize(image[i], (patchsize,patchsize))
        outs = model.predict(np.array([image_tran]))
        predicted = np.argmax(outs)
        if label[i][predicted] == 1:
            acc+=1
    
    print("Number of pictures predicted correctly by model: %d" % acc)
    print("Number of picutres in the dataset: %d" % len(X))

    return acc/len(X)

# Compute Model Performance
v1_training_augmented = accuracy(X_train_example, y_train_example, cse217_v1_augmented) 
print("Model accuracy on cse217_v1_augmented training data:  ", v1_training_augmented)
v2_training_augmented = accuracy(X_train_example, y_train_example, cse217_v2_augmented) 
print("Model accuracy on cse217_v2_augmented training data:  ", v2_training_augmented)

v1_val_augmented = accuracy(X_val_example, y_val_example, cse217_v1_augmented) 
print("Model accuracy on cse217_v1_augmented validation data:  ", v1_val_augmented)
v2_val_augmented = accuracy(X_val_example, y_val_example, cse217_v2_augmented) 
print("Model accuracy on cse217_v2_augmented validation data:  ", v2_val_augmented)

v1_test_augmented = accuracy(X_test_example, y_test_example, cse217_v1_augmented) 
print("Model accuracy on cse217_v1_augmented test data:  ", v1_test_augmented)
v2_test_augmented = accuracy(X_test_example, y_test_example, cse217_v2_augmented) 
print("Model accuracy on cse217_v2_augmented test data:  ", v2_test_augmented)
# Out:
# Number of pictures predicted correctly by model: 514
# Number of picutres in the dataset: 784
# Model accuracy on cse217_v1_augmented training data:   0.6556122448979592
# Number of pictures predicted correctly by model: 626
# Number of picutres in the dataset: 784
# Model accuracy on cse217_v2_augmented training data:   0.798469387755102
# Number of pictures predicted correctly by model: 123
# Number of picutres in the dataset: 195
# Model accuracy on cse217_v1_augmented validation data:   0.6307692307692307
# Number of pictures predicted correctly by model: 142
# Number of picutres in the dataset: 195
# Model accuracy on cse217_v2_augmented validation data:   0.7282051282051282
# Number of pictures predicted correctly by model: 13
# Number of picutres in the dataset: 15
# Model accuracy on cse217_v1_augmented test data:   0.8666666666666667
# Number of pictures predicted correctly by model: 12
# Number of picutres in the dataset: 15
# Model accuracy on cse217_v2_augmented test data:   0.8

# %% [raw]
# # your response here
#
#                       | training acc | validation acc | testing acc
#             cse217_v1 |     0.46     |      0.43      |    0.6
#   cse217_v1_augmented |     0.66     |      0.63      |    0.86
#
#
#                       | training acc | validation acc | testing acc
#             cse217_v2 |     0.57     |      0.47      |    0.73
#   cse217_v2_augmented |     0.80     |      0.73      |    0.8
#
# 1. Data augmentation definitely helped increase accuracy of the model becasue either in v1 or v2 the augmented model always had better performance than the regular model.
# 2. v2 benefitted more from data augmentation
# 3. The difference may be because v1, v2 take in different parameters and they have different amount of convolutional layers. The process of processing data is thus different. So they benefit differently from data augmentation.

# %% [markdown]
# ### Problem 6
#
# Now, let's have some fun!
#
# Let's explore a _real-time_ version of the model you identified as performing best running with your webcam. Open a new terminal window (on Mac OS you will need to use the built-in terminal app) and navigate to the directory, where you stored the model. Once there, run the following command, substituting `<model_name>` for the name of the file containing your model:
#
# ```
# $ python(3) realtime.py <model_name>
# ```
#
# Have fun!
#
# Note, `realtime.py` uses opencv, so you miht need to install it:
#
# - **opencv**: `pip(3) install opencv-python`
#
#
# **Write-up**  Summarize the performance of our NN model.
# - When does it work well, when does it have difficulties in predicting the correct gesture? Consider angle, background, and distance in your answer.
# - Which of the three classes get predicted more correctly, which of the classes get mistaken for what other classes more frequently?

# %% [raw]
# # your response here

# %% [markdown]
# And that's it! Remember to review your work and make sure it is well presented and organized. Not everyting you coded up needs to remain in your submission, infact for this hw, we arenot expecting any code submission. **[Does [this cell] spark joy?](https://i.kinja-img.com/gawker-media/image/upload/s--iW_3HGbT--/c_scale,dpr_2.0,f_auto,fl_progressive,q_80,w_800/oruf4oavtj5vpmvaquew.jpg)** You are always trying to communicate your findings to somebody, _maybe even yourself_.
